# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from dotenv import load_dotenv
from langchain_groq import ChatGroq
import os
load_dotenv()
# Out:
# True

# %%
model =ChatGroq(
    model="llama-3.3-70b-versatile",    
    api_key=os.getenv("GROQ_API_KEY"),
)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': "**Title:** The Rise of AI in India: Opportunities, Challenges, and the Future\n\n**I. Introduction**\n  * Brief overview of Artificial Intelligence (AI) and its global impact\n  * Importance of AI in the modern world\n  * Thesis statement: India is emerging as a significant player in the global AI landscape, with the potential to drive innovation, economic growth, and social change.\n\n**II. Current State of AI in India**\n  * Overview of the Indian AI ecosystem\n  * Key sectors driving AI adoption in India (e.g., IT, healthcare, finance, education)\n  * Government initiatives and policies supporting AI development (e.g., National AI Strategy, AI Task Force)\n  * Notable AI startups and companies in India (e.g., Infosys, Wipro, Tata Consultancy Services)\n\n**III. Opportunities in AI for India**\n  * Economic benefits: job creation, increased productivity, and competitiveness\n  * Social benefits: improved healthcare, education, and public services\n  * Innovation opportunities: AI research and development, entrepreneurship, and innovation hubs\n  * Case studies of successful AI implementations in India (e.g., AI-powered chatbots, predictive maintenance)\n\n**IV. Challenges Facing AI Adoption in India**\n  * Infrastructure and resource constraints (e.g., data quality, computing power, talent availability)\n  * Regulatory and ethical concerns (e.g., data privacy, bias, job displacement)\n  * Skills gap and talent acquisition challenges\n  * Cybersecurity threats and risks associated with AI adoption\n\n**V. Future of AI in India**\n  * Emerging trends and technologies (e.g., edge AI, explainable AI, AI for social good)\n  * Potential applications of AI in India (e.g., agriculture, transportation, energy)\n  * Role of government, industry, and academia in shaping the future of AI in India\n  * Predictions and forecasts for the Indian AI market\n\n**VI. Conclusion**\n  * Recap of the rise of AI in India\n  * Call to action: encouraging stakeholders to invest in AI development, adoption, and innovation\n  * Final thoughts: the potential of AI to transform India's economy, society, and future\n\n**Additional Sections (Optional)**\n  * **VII. AI in Indian Industries**\n    + In-depth analysis of AI adoption in specific industries (e.g., healthcare, finance, manufacturing)\n    + Case studies and success stories of AI implementation in these industries\n  * **VIII. AI Education and Skills Development**\n    + Overview of AI education and training programs in India\n    + Importance of developing AI skills and talent in India\n    + Initiatives and resources for AI education and skills development\n  * **IX. AI Ethics and Regulatory Framework**\n    + Discussion of AI ethics and regulatory challenges in India\n    + Overview of existing regulatory frameworks and guidelines\n    + Recommendations for developing a comprehensive AI regulatory framework in India\n\nThis detailed outline provides a comprehensive structure for a blog on the rise of AI in India, covering the current state, opportunities, challenges, and future prospects of AI in the country.", 'content': "**The Rise of AI in India: Opportunities, Challenges, and the Future**\n\n**I. Introduction**\n\nArtificial Intelligence (AI) has been transforming the world in unprecedented ways, with its impact felt across various sectors and industries. From virtual assistants to self-driving cars, AI has become an integral part of our daily lives. The importance of AI in the modern world cannot be overstated, as it has the potential to drive innovation, economic growth, and social change. India, with its vast talent pool, growing economy, and favorable business environment, is emerging as a significant player in the global AI landscape. In this blog, we will explore the rise of AI in India, its opportunities, challenges, and future prospects.\n\n**II. Current State of AI in India**\n\nThe Indian AI ecosystem is rapidly evolving, with key sec ...

# %%
print(final_state['outline'])
# Out:
# **Title:** The Rise of AI in India: Opportunities, Challenges, and the Future
#
# **I. Introduction**
#   * Brief overview of Artificial Intelligence (AI) and its global impact
#   * Importance of AI in the modern world
#   * Thesis statement: India is emerging as a significant player in the global AI landscape, with the potential to drive innovation, economic growth, and social change.
#
# **II. Current State of AI in India**
#   * Overview of the Indian AI ecosystem
#   * Key sectors driving AI adoption in India (e.g., IT, healthcare, finance, education)
#   * Government initiatives and policies supporting AI development (e.g., National AI Strategy, AI Task Force)
#   * Notable AI startups and companies in India (e.g., Infosys, Wipro, Tata Consultancy Services)
#
# **III. Opportunities in AI for India**
#   * Economic benefits: job creation, increased productivity, and competitiveness
#   * Social benefits: improved healthcare, education, and public services
#   * Innovation opportunities: AI research and development, entrepreneurship, and innovation hubs
#   * Case studies of successful AI implementations in India (e.g., AI-powered chatbots, predictive maintenance)
#
# **IV. Challenges Facing AI Adoption in India**
#   * Infrastructure and resource constraints (e.g., data quality, computing power, talent availability)
#   * Regulatory and ethical concerns (e.g., data privacy, bias, job displacement)
#   * Skills gap and talent acquisition challenges
#   * Cybersecurity threats and risks associated with AI adoption
#
# **V. Future of AI in India**
#   * Emerging trends and technologies (e.g., edge AI, explainable AI, AI for social good)
#   * Potential applications of AI in India (e.g., agriculture, transportation, energy)
#   * Role of government, industry, and academia in shaping the future of AI in India
#   * Predictions and forecasts for the Indian AI market
#
# **VI. Conclusion**
#   * Recap of the rise of AI in India
#   * Call to action: encouraging stakeholders to invest in AI development, adoption, and innovation
#   * Final thoughts: the potential of AI to transform India's economy, society, and future
#
# **Additional Sections (Optional)**
#   * **VII. AI in Indian Industries**
#     + In-depth analysis of AI adoption in specific industries (e.g., healthcare, finance, manufacturing)
#     + Case studies and success stories of AI implementation in these industries
#   * **VIII. AI Education and Skills Development**
#     + Overview of AI education and training programs in India
#     + Importance of developing AI skills and talent in India
#     + Initiatives and resources for AI education and skills development
#   * **IX. AI Ethics and Regulatory Framework**
#     + Discussion of AI ethics and regulatory challenges in India
#     + Overview of existing regulatory frameworks and guidelines
#     + Recommendations for developing a comprehensive AI regulatory framework in India
#
# This detailed outline provides a comprehensive structure for a blog on the rise of AI in India, covering the current state, opportunities, challenges, and future prospects of AI in the country.

# %%
print(final_state['content'])

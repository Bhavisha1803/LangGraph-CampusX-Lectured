# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver
import os   
load_dotenv()
# Out:
# True

# %%
llm =ChatGroq(
    model="llama-3.3-70b-versatile",    
    api_key=os.getenv("GROQ_API_KEY"),
)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood. \n\nBecause it was feeling a little crusty.',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood. \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a play on words. \n\nIn this joke, "crusty" has a double meaning. In one sense, the crust is a part of a pizza, referring to the outer layer of the pizza that is typically crunchy and golden brown. \n\nHowever, "crusty" also has an idiomatic meaning, which is to describe someone or something as being irritable, grumpy, or having a bad temper. For example, you might say "He\'s been a bit crusty all day" to mean that someone is in a bad mood.\n\nThe joke relies on this wordplay, using the literal meaning of "crusty" (the pizza\'s crust) and the idiomatic meaning (being in a bad mood) to create a pun. The punchline "it was feeling a little crusty" is humorous because it takes the expected meaning of "crusty" (the pizza\'s crust) and subverts it to create a clev
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood. \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a play on words. \n\nIn this joke, "crusty" has a double meaning. In one sense, the crust is a part of a pizza, referring to the outer layer of the pizza that is typically crunchy and golden brown. \n\nHowever, "crusty" also has an idiomatic meaning, which is to describe someone or something as being irritable, grumpy, or having a bad temper. For example, you might say "He\'s been a bit crusty all day" to mean that someone is in a bad mood.\n\nThe joke relies on this wordplay, using the literal meaning of "crusty" (the pizza\'s crust) and the idiomatic meaning (being in a bad mood) to create a pun. The punchline "it was feeling a little crusty" is humorous because it takes the expected meaning of "crusty" (the pizza\'s crust) and subverts it to create a cle
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti refuse to get married. \n\nBecause it was afraid of getting tangled up in a relationship.',
# ...

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti refuse to get married. \n\nBecause it was afraid of getting tangled up in a relationship.', 'explanation': 'The joke "Why did the spaghetti refuse to get married. Because it was afraid of getting tangled up in a relationship" is a play on words. \n\nThe phrase "tangled up" has a double meaning here. In a literal sense, spaghetti is a type of long, thin, and flexible pasta that can easily become tangled or knotted. However, in a figurative sense, "tangled up" is also an idiom that means to become deeply involved or entangled in a complicated situation, often referring to romantic relationships.\n\nThe joke relies on this wordplay, using the physical properties of spaghetti (its tendency to get tangled) to make a humorous comment on the complexities and potential pitfalls of romantic relationships. The punchline suggests that the spaghetti is hesitant to get married because it\'s afraid of becoming emotionally entan
# ...

# %%
snapshot_for_config2 = list(workflow.get_state_history(config2))

# %%
snapshot_for_config2[-1]
# Out:
# StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f130b40-8f98-66ae-bfff-3545b32924c4'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-05T05:55:22.801311+00:00', parent_config=None, tasks=(PregelTask(id='1e321db3-9402-1852-b03d-2718c7699a1f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pasta'}),), interrupts=())

# %%
topic = snapshot_for_config2[0].values.get('topic')
print(topic)
# Out:
# pasta

# %%
# Time travel

# %%
workflow.get_state({"configurable": {"thread_id": "2", "checkpoint_id": "1f130b40-9304-6d56-8001-fcc3addb016a"}})
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti refuse to get married. \n\nBecause it was afraid of getting tangled up in a relationship.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_id': '1f130b40-9304-6d56-8001-fcc3addb016a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-05T05:55:23.160282+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f130b40-8f9b-6386-8000-a73aa9574b3b'}}, tasks=(PregelTask(id='9c598ce2-df17-8b2c-a88b-61f533b31494', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the spaghetti refuse to get married. Because it was afraid of getting tangled up in a relationship" is a play on words. \n\nThe phrase "tangled up" has a double meaning here. In a literal sense, spaghetti is a type of long, thin, and flexible pasta 
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "2", "checkpoint_id": "1f130b40-8f98-66ae-bfff-3545b32924c4"}})
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti refuse to get married. \n\nBecause it was afraid of getting tangled up in a relationship.',
# ...

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti refuse to get married. \n\nBecause it was afraid of getting tangled up in a relationship.', 'explanation': 'The joke "Why did the spaghetti refuse to get married. Because it was afraid of getting tangled up in a relationship" is a play on words. It uses the physical properties of spaghetti, which is a long, thin, and flexible type of pasta that can easily become tangled or knotted, to create a pun.\n\nIn this joke, the phrase "tangled up" has a double meaning. Literally, spaghetti can become tangled or knotted when it\'s not properly cooked or stored. However, in the context of relationships, "tangled up" is also an idiomatic expression that means to become deeply involved or entangled in a complicated situation, often in a romantic or emotional sense.\n\nThe joke relies on this wordplay to create humor. The punchline "it was afraid of getting tangled up in a relationship" is a clever and unexpected twist on the 
# ...

# %%
# Updating state

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood. \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a play on words. \n\nIn this joke, "crusty" has a double meaning. In one sense, the crust is a part of a pizza, referring to the outer layer of the pizza that is typically crunchy and golden brown. \n\nHowever, "crusty" also has an idiomatic meaning, which is to describe someone or something as being irritable, grumpy, or having a bad temper. For example, you might say "He\'s been a bit crusty all day" to mean that someone is in a bad mood.\n\nThe joke relies on this wordplay, using the literal meaning of "crusty" (the pizza\'s crust) and the idiomatic meaning (being in a bad mood) to create a pun. The punchline "it was feeling a little crusty" is humorous because it takes the expected meaning of "crusty" (the pizza\'s crust) and subverts it to create a cle
# ...

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f130b98-84c2-65ec-8000-d22b3b12ec4c'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f130b98-84c2-65ec-8000-d22b3b12ec4c'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-04-05T06:34:43.897080+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='c4a52399-0836-8a11-eff0-b73fa4566507', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f130b98-84c2-65ec-8000-d22b3b12ec4c"}})
# Out:
# {'topic': 'samosa',
#  'joke': 'Why did the samosa go to therapy?\n\nBecause it was feeling a little "crusty" and had a lot of "filling" emotional issues to work through.',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': 'Why did the samosa go to therapy?\n\nBecause it was feeling a little "crusty" and had a lot of "filling" emotional issues to work through.', 'explanation': 'This joke is a play on words, using the characteristics of a samosa (a type of fried or baked pastry) to create a pun-filled punchline. \n\nThe joke starts by setting up the idea that a samosa is going to therapy, which is a unexpected and humorous concept. The punchline then uses two key words: "crusty" and "filling".\n\n"Crusty" has a double meaning here. In a literal sense, a samosa is a pastry that is often crispy and crusty on the outside. However, the word "crusty" can also be used to describe someone who is gruff, irritable, or has a tough exterior. In this joke, the samosa is feeling "a little crusty", implying that it\'s not just referring to its physical state, but also its emotional state - it\'s feeling a bit rough around the edges.\n\nThe second part of the punchline
# ...
